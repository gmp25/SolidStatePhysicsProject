# %%
"""Final Project"""

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 100
a = 1

electronarray = np.arange(1,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
b= np.random.randint(0,100)
for i in range(N):
    c = np.random.randint(100)  #to maintain randomness, keep N and the random integer bound equal
    locarrayx[i] = c * 3.*a / 2
    locarrayx += a
    b = (np.random.randint(100) * a * np.sqrt(3))
    if c % 2 == 0:
        locarrayy[i] =  b
    else:
        locarrayy[i] = b + a * np.sqrt(3) / 2.
plt.plot(locarrayx)
plt.plot(locarrayy)

# %%
plt.scatter(locarrayx,locarrayy)
plt.title("Initial points of N electrons scattered throughout the hexagonal lattice")

# %%
jtype = np.zeros(N)

def motions(x, y, jtype, rand):
    #import numpy as np
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
    else:
        if rand < 0.2:
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t):
    locarrayx = np.zeros(t)
    locarrayy = np.zeros(t)
    jtype = np.zeros(t)
    rand = np.zeros(t)
    for i in range(99):
        rand[i] = np.random.rand()
        a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
        locarrayx[i+1] = a[0] 
        locarrayy[i+1] = a[1] 
        jtype[i+1] = a[2]
    plt.plot(locarrayx,locarrayy, 'ko-')
    plt.gca().set_aspect('equal')
    plt.grid()
    
call_function(locarrayx,locarrayy,jtype,100)

# %%
"""Attempt to do for all electrons"""

def motions(x, y, jtype, rand):
    #import numpy as np
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
    else:
        if rand < 0.2:
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t):
    locarrayx = np.zeros(t)
    locarrayy = np.zeros(t)
    jtype = np.zeros(t)
    rand = np.zeros(t)
    for j in range(t):
        for i in range(99):
            rand[i] = np.random.rand()
            a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
            locarrayx[i+1] = a[0] 
            locarrayy[i+1] = a[1] 
            jtype[i+1] = a[2]
        plt.plot(locarrayx,locarrayy)
    plt.gca().set_aspect('equal')
    plt.grid()
    
call_function(locarrayx,locarrayy,jtype,100)

# %%
def motions(x, y, jtype, rand):
    #import numpy as np
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
    else:
        if rand < 0.2:
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t,N):
    a = 1.0
    locarrayx = np.zeros(N+1)
    locarrayy = np.zeros(N+1)
    jtype = np.zeros(N+1)
    rand = np.zeros(N+1)
    for j in range(t):
        a = 1.0
        c = np.random.randint(10) 
        locarrayx[0] = c * 3.*a / 2
        locarrayx[0] += a
        b = (np.random.randint(100) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[0] =  b
        else:
            locarrayy[0] = b + a * np.sqrt(3) / 2.    
        for i in range(N):
            rand[i] = np.random.rand()
            a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
            locarrayx[i+1] = a[0] 
            locarrayy[i+1] = a[1] 
            jtype[i+1] = a[2]
        plt.plot(locarrayx,locarrayy)
    plt.grid()
call_function(locarrayx,locarrayy,jtype,100,101)

# %% [markdown]
# Find the expected displacement for each step, and then compare this to the average displacement found with the above code for a high number of time steps

# %% [markdown]
# Below we see the results of our test case: a single electron moving coherently throughout the hexagonal lattice. Although
# the coherent movement seen is encouraging, it does not looking quite hexagonal in nature and therefore our next portion will be
# focusing on ironing out this. So far we have achieved this movement as well as the random scattering of initial placement of
# electrons, as shown above

# %%
"""May be used later"""

for i in range(N):
            rand[i] = np.random.rand()
            a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
            locarrayx[i] = a[0] #first value
            locarrayy[i] = a[1] #second value
            xevol.extend([locarrayx[i]])
            yevol.extend([locarrayy[i]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-7cb02e00179d> in <module>()
#       2
#       3 for i in range(N):
# ----> 4             rand[i] = np.random.rand()
#       5             a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
#       6             locarrayx[i] = a[0] #first value
#
# NameError: name 'rand' is not defined

# %%
print(np.sqrt((locarrayx[i]-locarrayx[i-1])**2+(locarrayy[i]-locarrayy[i-1])**2))

# %%
print(0%2)
# Out:
# 0
